# %%
import pandas as pd
import spacy
import string
nlp = spacy.load('en_core_web_lg') # Need to install the corpus: space download n_core_web_lg

# %%
ticker = pd.read_csv('../data/asx-tickers.csv')
headlines = pd.read_csv('../data/scraped/combined_headlines.csv')

# %%
# Clean up the headlines (lightly) - drop excess characters and duplicates
stripped = headlines.titles.apply(lambda x: x.strip('"\' ' ))
headlines_clean = headlines[~headlines.titles.duplicated(keep='first')]

# Drop records that don't have any company words
translator = str.maketrans('','',string.punctuation)

def normalize(s):
    return s.lower().translate(translator).split()

def incompwords(s):
    headwords = set(normalize(s))
    return len(headwords & compwords) > 0

compwords = set(normalize((" ".join(ticker['company'].values))))
headlines_filtered = headlines_clean[headlines_clean.titles.apply(incompwords)]

print("Headlines with company names: ",headlines_filtered.shape[0])
headlines_filtered.head(3)
# Out:
# Headlines with company names:  592608
#    Unnamed: 0        date                                  titles
# 0           0  2006-01-01   Russia completes Ukraine gas cut-off
# 1           1  2006-01-01                 High winds cause havoc
# 3           3  2006-01-01                   Russia takes over G8

# %%
# Find the subject of a sentence and ORG entities in a sentence.
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")
sub_toks = [tok for tok in doc if (tok.dep_ == "nsubj") ]
print(sub_toks)
org_toks = [ent.text for ent in doc.ents if (ent.label_ == "ORG")]
print(org_toks)
# Out:
# [Apple]
# ['Apple']

# %%
# Apply Spacy to a dataframe
subjects = []
orgs = []

sample_test = headlines_filtered.head(1000)

for doc in nlp.pipe(sample_test['titles'].astype('unicode').values, batch_size=50,
                        n_threads=3):
    if doc.is_parsed:
        subjects.append([tok for tok in doc if (tok.dep_ == "nsubj")])
        orgs.append([ent.text for ent in doc.ents if (ent.label_ == "ORG")])
    else:
        # We want to make sure that the lists of parsed results have the
        # same number of entries of the original Dataframe, so add some blanks in case the parse fails
        subjects.append(None)
        orgs.append(None)

sample_test['subject'] = subjects
sample_test['orgs'] = orgs
sample_test.head(500)
# Out:
# /Users/Koss/miniconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/Koss/miniconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      Unnamed: 0        date  \
# 0             0  2006-01-01
# 1             1  2006-01-01
# 3             3  2006-01-01
# 4             4  2006-01-01
# 7             7  2006-01-01
# 8             8  2006-01-01
# 9             9  2006-01-01
# 10           10  2006-01-01
# 11           11  2006-01-01
# 13           13  2006-01-01
# 15           15  2006-01-01
# 18           18  2006-01-01
# 21           21  2006-01-01
# 25           25  2006-01-01
# 26           26  2006-01-01
# 28           28  2006-01-01
# 29           29  2006-01-01
# 32           32  2006-01-01
# 33           33  2006-01-01
# 34           34  2006-01-01
# 36           36  2006-01-01
# 39           39  2006-01-01
# 40           40  2006-01-01
# 41           41  2006-01-01
# 43           43  2006-01-01
# 45           45  2006-01-01
# 46           46  2006-01-01
# 47           47  2006-01-01
# 48           48  2006-01-01
# 50           50  2006-01-01
# ..          ...         ...
# 794         794  2006-01-05
# 795         795  2006-01-05
# 798         798  2006-01-05
# 801         801  2006-01-05
# 802         802  2006-01-05
# 803         803  2006-01-05
# 805         805  2006-01-05
# 809         809  2006-01-05
# 814         814  2006-01-05
# 816         816  2006-01-05
# 817         817  2006-01-05
# 819         819  2006-01-05
# 820         820  2006-01-05
# 822         822  2006-01-05
# 823         823  2006-01-05
# 824         824  2006-01-05
# 826         826  2006-01-05
# 827         827  2006-01-05
# 828         828  2006-01-05
# 829         829  2006-01-05
# 833         833  2006-01-05
# 835         835  2006-01-05
# 838         838  2006-01-05
# 840         840  2006-01-05
# 841         841  2006-01-05
# 845         845  2006-01-05
# 847         847  2006-01-05
# 848         848  2006-01-05
# 850         850  2006-01-05
# 851         851  2006-01-05
#
#                                                 titles                subject  \
# 0                Russia completes Ukraine gas cut-off                [Russia]
# 1                              High winds cause havoc                 [winds]
# 3                                Russia takes over G8                [Russia]
# 4                Turkish children tested for bird flu              [children]
# 7                 Adelaide notch 4-2 win against Roar                      []
# 8     Famine a national disaster, Kenyan President ...            [President]
# 9                Adelaide trounce Roar to extend lead                      []
# 10    Aust fire crews aid fight against New Caledon...                [crews]
# 11                Man questioned over Valley stabbing                   [Man]
# 13                  Sydney records record temperature                [Sydney]
# 15                                World welcomes 2006                 [World]
# 18      Proteas turning to spinners against Australia                      []
# 21              US triumph over Serbia and Montenegro                      []
# 25                    Progress made against NSW fires                      []
# 26                Ferguson bows out on the Gold Coast              [Ferguson]
# 28                          Beached whales shot in NZ                [whales]
# 29                    Fireworks and parties mark 2006             [Fireworks]
# 32           Bolder blocking Great Ocean Road removed                [Bolder]
# 33                     Five dead in SA road accidents                      []
# 34    Indonesian police detain man after market bom...               [police]
# 36                   Fires threaten NSW central coast                 [Fires]
# 39             Iraqi baby arrives for treatment in US                  [baby]
# 40             Anti-poverty campaign was 'a big step'              [campaign]
# 41               Severe flooding hits US wine regions              [flooding]
# 43          Fires threaten homes on NSW central coast                 [Fires]
# 45                   Thousands without power in Unley                      []
# 46                             Fire in unit kills one                  [Fire]
# 47                          Arthurs out of Hopman Cup                      []
# 48      Ivanovic gives Serbia and Montenegro 1-0 lead              [Ivanovic]
# 50    One in three households not prepared for emer...                     []
# ..                                                 ...                    ...
# 794   Netherlands reach Hopman final after Kiefer p...  [Netherlands, Kiefer]
# 795   11 Indonesian captains face jail over illegal...             [captains]
# 798   NSW to open state forests for feral animal hunt                      []
# 801                     Agassi out of Australian Open                      []
# 802               MP urges regional tax rebate review                    [MP]
# 803         Gibbs run out as rain disrupts third Test           [Gibbs, rain]
# 805            IR campaign a waste of money, says ALP                   [ALP]
# 809      Thousands fined in year-end driver crackdown                      []
# 814                   Police seek info on Munro crash                [Police]
# 816               Police seek leads on Cooma shooting                [Police]
# 817   Farmers encouraged to aid rare snake's survival               [Farmers]
# 819           Ardrossan waits on funding announcement             [Ardrossan]
# 820              Opposition denies health policy rift            [Opposition]
# 822                       Boaties seek help with kelp               [Boaties]
# 823            Tait in Twenty20 comeback for Redbacks                      []
# 824       Australia pledges aid for landslide victims             [Australia]
# 826         US farmers to fight any FTA sugar changes               [farmers]
# 827             Water project moves closer to reality               [project]
# 828      Hot weather tests water, electricity systems                      []
# 829                A hot, wet year for SA's Riverland                      []
# 833   Charges expected over alleged school arson at...                     []
# 835        Poor maintenance leads to Portland rescues           [maintenance]
# 838                   Knights team up with local beer                      []
# 840                     Seven, 10 match offer by Nine                      []
# 841          $22 mangoes still appealing for tourists               [mangoes]
# 845                     Nadal in fresh doubt for Open                      []
# 847    DPI investigates Hunter Valley mining accident                   [DPI]
# 848   Meeting planned to discuss Inskip Pt camping ...              [Meeting]
# 850               Man charged over $400,000 drug haul                   [Man]
# 851                Firefighter calls for more funding           [Firefighter]
#
#            orgs
# 0            []
# 1            []
# 3            []
# 4            []
# 7            []
# 8            []
# 9            []
# 10           []
# 11           []
# 13           []
# 15           []
# 18           []
# 21           []
# 25        [NSW]
# 26   [Ferguson]
# 28           []
# 29           []
# 32           []
# 33           []
# 34           []
# 36           []
# 39           []
# 40           []
# 41           []
# 43           []
# 45           []
# 46           []
# 47           []
# 48           []
# 50           []
# ..          ...
# 794          []
# 795          []
# 798          []
# 801          []
# 802          []
# 803          []
# 805   [IR, ALP]
# 809          []
# 814          []
# 816     [Cooma]
# 817   [Farmers]
# 819          []
# 820          []
# 822          []
# 823      [Tait]
# 824          []
# 826          []
# 827          []
# 828          []
# 829          []
# 833          []
# 835          []
# 838          []
# 840          []
# 841          []
# 845          []
# 847          []
# 848          []
# 850          []
# 851          []
#
# [500 rows x 5 columns]

# %%
# Attempt to match subjects to companies
tick_df = ticker.copy();
companies = tick_df['company'].apply(lambda x: x.title()).tolist()

def find_most(word):
    max_sim = ('', 0)
    if type(word) is list:
        for token in word:
            for company in companies:
                company = nlp(company)
                sim = token.similarity(company)
                if sim > max_sim[1]:
                    max_sim = (company, sim)
    else:
        for company in companies:
            company = nlp(company)
            sim = word.similarity(company)
            if sim > max_sim[1]:
                max_sim = (company, sim)
    return max_sim
sample_test['subject_sim'] = sample_test['subject'].apply(find_most)
sample_test.head(500)

# # Compute Similarity to Subjects
# sub_sims = []
# for doc in nlp.pipe(sample_test['subject'].astype('unicode').values, batch_size=50, n_threads=3):
#     if doc.is_parsed:
#         max_sim = ('', 0)
#         for token in doc:
#             for company in companies:
#                 sim = token.similarity(company)
#                 if sim > max_sim[1]:
#                     max_sim = (company, sim)
#         sub_sums.append(max_sim[0])
#     else:
#         sub_sims.append(None)
# sample_test['subject_sim'] = sub_sims
# sample_test.head(500)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-72cb20694299> in <module>()
#      19                 max_sim = (company, sim)
#      20     return max_sim
# ---> 21 sample_test['subject_sim'] = sample_test['subject'].apply(find_most)
#      22 sample_test.head(500)
#      23
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-37-72cb20694299> in find_most(word)
#       8         for token in word:
#       9             for company in companies:
# ---> 10                 company = nlp(company)
#      11                 sim = token.similarity(company)
#      12                 if sim > max_sim[1]:
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/spacy/language.py in __call__(self, text, disable)
#     350             if not hasattr(proc, '__call__'):
#     351                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 352             doc = proc(doc)
#     353             if doc is None:
#     354                 raise ValueError(Errors.E005.format(name=name))
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.__call__()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.parse_batch()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.get_batch_model()
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/thinc/api.py in begin_update(self, X, drop)
#      59         callbacks = []
#      60         for layer in self._layers:
# ---> 61             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      62             callbacks.append(inc_layer_grad)
#      63         def continue_update(gradient, sgd=None):
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/thinc/api.py in begin_update(seqs_in, drop)
#     278         lengths = layer.ops.asarray([len(seq) for seq in seqs_in])
#     279         X, bp_layer = layer.begin_update(layer.ops.flatten(seqs_in, pad=pad),
# --> 280                                          drop=drop)
#     281         if bp_layer is None:
#     282             return layer.ops.unflatten(X, lengths, pad=pad), None
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/thinc/api.py in begin_update(self, X, drop)
#      59         callbacks = []
#      60         for layer in self._layers:
# ---> 61             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      62             callbacks.append(inc_layer_grad)
#      63         def continue_update(gradient, sgd=None):
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/thinc/neural/_classes/resnet.py in begin_update(self, X, drop)
#      16
#      17     def begin_update(self, X, drop=0.):
# ---> 18         y, bp_y = self._layers[0].begin_update(X, drop=drop)
#      19         output = X+y
#      20         def residual_bwd(d_output, sgd=None):
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/thinc/api.py in begin_update(self, X, drop)
#      59         callbacks = []
#      60         for layer in self._layers:
# ---> 61             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      62             callbacks.append(inc_layer_grad)
#      63         def continue_update(gradient, sgd=None):
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/thinc/neural/_classes/convolution.py in begin_update(self, X__bi, drop)
#      27     def begin_update(self, X__bi, drop=0.0):
#      28         X__bo = self.ops.seq2col(X__bi, self.nW)
# ---> 29         finish_update = self._get_finish_update()
#      30         return X__bo, finish_update
#      31
#
# ~/miniconda3/envs/py36/lib/python3.6/site-packages/thinc/neural/_classes/convolution.py in _get_finish_update(self)
#      30         return X__bo, finish_update
#      31
# ---> 32     def _get_finish_update(self):
#      33         def finish_update(gradient, sgd=None):
#      34             return self.ops.backprop_seq2col(gradient, self.nW)
#
# KeyboardInterrupt:
